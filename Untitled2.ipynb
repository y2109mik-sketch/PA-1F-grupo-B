# %% [markdown]
# <a href="https://colab.research.google.com/github/y2109mik-sketch/PA-1F-grupo-B/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#entrada
comprimento = float(input("digite o comprimento do retangulo:"))
altura = float(input("digite a altura do retangulo"))

#processamento

area = comprimento * altura

#saida

print (f"o total da área do retangulo é:{area}")
# Out:
# digite o comprimento do retangulo:6
# digite a altura do retangulo3
# o total da área do retangulo é:18.0

# %% [markdown]
# fazer um cadastro de usuario:
#
# Objetivo trabalhar com string (str)
#
# entrada de dados:Nome e idade Processamento:armazenar os dados Saida: mostrar uma mensagem de olá e a idade do usuario

# %% [markdown]
# calcular a area do retangulo

# %%
#entrada
nome = str(input("digite seu nome: "))
idade = int(input("digite sua idade: "))

#saida

print (f"ola {nome}, seja bem vindo!")
print (f"você tem {idade} anos.")
# Out:
# digite seu nome: arthur
# digite sua idade: 15
# ola arthur, seja bem vindo!
# você tem 15 anos.

# %% [markdown]
# fazer um programa de calcular o dobro de um numero
#
# entrada: um número
#
# Processamento: Calcular o dobro
#
# Saída: moostrar o resultado

# %% [markdown]
# escrever um programa que calcula a media das notas do aluno
#
# entrada: nome, idade, e as 04 notas do bimestre
#
# processamento calcular a media
#
# saida: mostrar o nome do aluno e a media

# %%
#entrada
numero = float(input("digite um numero"))

#processamento

dobro = numero + numero

#saida
print(f"o dobro do numero {numero} é igual a {dobro}")
# Out:
# digite um numero3
# o dobro do numero 3.0 é igual a 6.0

# %%
#entrada

nome = str(input("digite o seu nome"))

idade = int(input("digite sua idade"))

nota1 = float(input("digite sua nota"))
nota2 = float(input("digite sua nota"))
nota3 = float(input("digite sua nota"))
nota4 = float(input("digite sua nota"))


#processamento
nota = ( nota1 + nota2 + nota3 + nota4 ) / 4


#saida
print (f"ola {nome} seja bem vindo")

print (f"sua media e {nota}")

print (f"voce tem {idade} anos")
# Out:
# digite o seu nomearthur
# digite sua idade7
# digite sua nota8
# digite sua nota9
# digite sua nota4
# digite sua nota5
# ola arthur seja bem vindo
# sua media e 6.5
# voce tem 7 anos
