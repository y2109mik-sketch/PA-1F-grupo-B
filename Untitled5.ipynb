# %% [markdown]
# <a href="https://colab.research.google.com/github/y2109mik-sketch/PA-1F-grupo-B/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#par ou impar


#entrada

n = int(input("digite um numero"))

#processamento

par = n + n
impar = n - 1

#saida

if n + n
 print(f"este numero é par")


 if n - 1
   print(f"este numero é impar")
# Out:
#   File "/tmp/ipykernel_4608/1065513253.py", line 15
#     if n + n
#             ^
# SyntaxError: expected ':'

# %%
#maior ou igual


 n1 = int(input("digite outro numero"))
 n2 = int(input("digite outro numero"))

 if n1 > n2
  print(f"o numero {n1} maior q {n2}")

 elif n1==n2
  print(f"o {n1} e igual a {n2}")

 else: n2 > n1
 print(f"o {n2} é maior q {n2}")
# Out:
#   File "/tmp/ipykernel_4608/2886474905.py", line 4
#     n1 = int(input("digite outro numero"))
#     ^
# IndentationError: unexpected indent

# %%
#nota

# Indentificar se o usuario é criança, adolescente ou adulto

# <= 7
# >= 7
# <= 5


#Entrada

numero= int(input(" sua nota"))


#Processamento/Saida

if numero >= 7:
  print(f"aprovado")

  if numero < 7:
    print(f"recuperação")

    if numero <= 5:
     print(f"reprovado")
# Out:
#  sua nota7
# aprovado

# %%
#comparacao de idade

# Indentificar se o usuario é criança, adolescente, adulto, idoso

# <= 12 criança
# <= 17 adolescente
# <= 59 adulto
# >=60 idoso


idade = int(input("digite sua idade"))

if idade: <= 12
print(f"=criança")

elif idade <=17
 print(f"adolescente")

 if idade <=59
  print(f"adulto")

 if idade >=60
  print(f"idoso")
# Out:
#   File "/tmp/ipykernel_4608/1221550672.py", line 13
#     if idade: <= 12
#               ^
# SyntaxError: invalid syntax

# %%
#senha

# %%
#calculadora

# operação aritimetica
# fazer um programa que calcula operações com 02 numeros

# Entrada

a = int(input("digite um numero: "))
b = int(input("digite um numero: "))

# Processamento

soma = a + b
subtracao = a - b
multiplicacao = a * b
divisao = a / b


# saída

print("")
print("-----------------------OPERADORES ARITIMETICOS----------------------")
print("")
print("--------------------------------SOMA--------------------------------")
print("")
print (f"o resultado da SOMA de {a} MAIS {b} é igual é: {soma} ")
print("")
print("")
print("-----------------------OPERADORES ARITIMETICOS----------------------")
print("")
print("------------------------------SUBTRAÇÃO-----------------------------")
print("")
print (f"o resultado da SUBTRAÇÃO de {a} MENOS {b} é igual é: {subtracao} ")
print("")
print("-----------------------OPERADORES ARITIMETICOS----------------------")
print("")
print("----------------------------MULTIPLICAÇÃO---------------------------")
print("")
print (f"o resultado da MULTIPLICAÇÃO de {a} MULTIPLICADO por {b} é igual é: {multiplicacao} ")
print("")
print("-----------------------OPERADORES ARITIMETICOS----------------------")
print("")
print("------------------------------DIVISÃO-------------------------------")
print("")
# Out:
# digite um numero: 4
# digite um numero: 6
#
# -----------------------OPERADORES ARITIMETICOS----------------------
#
# --------------------------------SOMA--------------------------------
#
# o resultado da SOMA de 4 MAIS 6 é igual é: 10
#
#
# -----------------------OPERADORES ARITIMETICOS----------------------
#
# ------------------------------SUBTRAÇÃO-----------------------------
#
# o resultado da SUBTRAÇÃO de 4 MENOS 6 é igual é: -2
#
# -----------------------OPERADORES ARITIMETICOS----------------------
#
# ----------------------------MULTIPLICAÇÃO---------------------------
#
# o resultado da MULTIPLICAÇÃO de 4 MULTIPLICADO por 6 é igual é: 24
#
# -----------------------OPERADORES ARITIMETICOS----------------------
#
# ------------------------------DIVISÃO-------------------------------
#
# o resultado da DIVISÃO de 4 DIVIDIDO por 6 é igual é: 0.6666666666666666
