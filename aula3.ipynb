# %% [markdown]
# <a href="https://colab.research.google.com/github/y2109mik-sketch/PA-1F-grupo-B/blob/main/aula3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lado1=2
lado2=3

#calculo da area

area= lado1 *lado2

#calculo da area do quadrado

areaquadrado= lado1 *lado1

# %%
print(area)
# Out:
# 6

# %%
nome="yasmin"
altura="1.90"
idade="15"

# %%
print(f"nome: {nome}, altura: {altura}, idade: {idade}")
# Out:
# nome: yasmin, altura: 1.90, idade: 15
