# %% [markdown]
# <a href="https://colab.research.google.com/github/y2109mik-sketch/PA-1F-grupo-B/blob/main/aulamarcio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#entrada

lado1= float(input("digite o comprimento:"))
lado2= float(input("digite a altura:"))

#processamento

area= lado1 * lado2

#saida

print(f"o total da area:{area} metros quadrados")
# Out:
# digite o comprimento:3
# digite a altura:9
# o total da area:27.0 metros quadrados

# %%
#entrada

numero = float(input("digite um numero:"))

#processamento


dobro = numero * 2

#saida


print(f"total do dobro:{dobro}")
# Out:
# digite um numero:10
# total do dobro:20.0

# %%
#entrada

numero1 = float(input("digite quatro numeros diferentes:"))
numero2 = float(input("digite quatro numeros diferentes:"))
numero3 = float(input("digite quatro numeros diferentes:"))
numero4 = float(input("digite quatro numeros diferentes:"))

#processamento


media =float(numero1 + numero2 + numero3 + numero4)/4


#saida

print(f" a media e igual a:{media}")
# Out:
# digite quatro numeros diferentes:7
# digite quatro numeros diferentes:8
# digite quatro numeros diferentes:7
# digite quatro numeros diferentes:8
#  a media e igual a:7.5

# %%
#entrada
nome = str(input("digite seu nome:"))
idade = int(input("digite sua idade"))


#saida
print(f"olá {nome}")
print(f"sua idade e {idade}")
# Out:
# digite seu nome:mas
# digite sua idade67
# olá mas
# sua idade e 67
